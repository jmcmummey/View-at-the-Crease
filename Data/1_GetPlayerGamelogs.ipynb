# %% [markdown]
# <h1>Gamelog Grabber</h1>
# <p>The following code scrapes the game logs for the 4000+ players in the inital directory and saves them to individual csvs.  Only seasons from the last 30 years (from 1990-1991 onwards) are considered.</p>

# %%
import pandas as pd
import numpy as np
import requests as r
import re
from bs4 import BeautifulSoup as bs

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 1000)

# %%
#import player list from csv and tidy 
players = pd.read_csv('nhlplayerlist_goalieonly.txt','\t')
players.drop(columns=['Unnamed: 0','index'],axis=1,inplace=True)
players.head(5)
# Out:
#               player  unique_id  year_start  year_finish position                                               link
# 0    David Aebischer  aebisda01        2001         2008        G  https://www.hockey-reference.com/players/a/aeb...
# 1   Sami Aittokallio  aittosa01        2013         2014        G  https://www.hockey-reference.com/players/a/ait...
# 2         Jake Allen  allenja01        2013         2020        G  https://www.hockey-reference.com/players/a/all...
# 3        Jorge Alves  alvesjo01        2017         2017        G  https://www.hockey-reference.com/players/a/alv...
# 4  Frederik Andersen  anderfr01        2014         2020        G  https://www.hockey-reference.com/players/a/and...

# %% [markdown]
# <h3>Functions to aid in Data Scrapping</h3>
# <p>The what follows are the functions used in the data collection<ul><li><p><strong>loglink</strong> - Gets the urls for each year the player played and returns it as a dictionary</p></li><li><p><strong>gamelogger</strong> - Grabs the game logs for each of the links entered and returns them as a DataFrame.</p></li></ul>
# </p>

# %%
def loglink(pwebsite):
    """
    Gets the urls for each year the player played and returns it as a dictionary
    input: (string) url for the player in question
    output: (dict) year/link pairs for each year the player competed
    """
    page = r.get(pwebsite)
    soup = bs(page.text,'html.parser')
    links = soup.find_all('a',href=True)

    #find the game log links
    gamelogs = [] #the list of the game log inks
    for l in links:
        if 'gamelog' in l['href']:
            gamelogs.append(l['href'])
    gamelogs = list(dict.fromkeys(gamelogs)) #remove duplicate entries

    #find the game logs
    gameloglinks = {} #a dictionary with the year:gameloglink
    for gl in gamelogs:
        reg = re.search(r'gamelog\/([\d]*)',gl)
        if reg[1]:
            gameloglinks[int(reg[1])] = gl
    return gameloglinks
def gamelogger(loglinks):
    """
    Grabs the game logs for each of the links entered and returns them as a DataFrame
    Input:  (dict) Year/Gamelog pairs
    Output: (dataframe) the entire post-1990 gamelog data (excluding playoffs) for that player
    """
    glogs = pd.DataFrame()
    #for every year after 1990 (1991 is the 1990-1991 season), grab the gamelogs
    column_names = []
    for key,value in loglinks.items():
        if key>1990:
            page = r.get('https://hockey-reference.com'+value)
            soup = bs(page.text,'html.parser')

            for eachitem in soup.find_all('tr',id=True): #for each row in table
                rowdata = []
                for eachc in eachitem.find_all('td'): #for each column in row
                    if glogs.empty:
                        column_names.append(eachc['data-stat'])
                    rowdata.append(eachc.text)
                if glogs.empty:
                    glogs = pd.DataFrame(columns=column_names)
                glogs = glogs.append(dict(zip(glogs.columns,rowdata)), ignore_index=True) 
    return glogs

# %% [markdown]
# <h3>Get the data</h3>
# <p>Data is aggregated and saved in tabs delimited format where each player is a different file and the name is the uniqueid.</p>

# %%
failed_players = [] #capture failed players
for i,player in players.iterrows():
    try:
        gamelogdict = loglink(player['link'])
    except:
        failed_players.append(player['player'])
        print("Failed to get gamelog links for %s" % (player['player']))
    try:
        log = gamelogger(gamelogdict)
    except:
        failed_players.append(player['player'])
        print("Error getting the gamelog for %s" % (player['player']))
    #write gamelog to csv for further analysis    
    log.to_csv('player_gamelogs\\'+player['unique_id']+'.txt')
    print('finished %d of %d or %.2f%%'%(i,players.shape[0],100*i/players.shape[0]))
# Out:
# finished 0 of 481 or 0.00%
# finished 1 of 481 or 0.21%
# finished 2 of 481 or 0.42%
# finished 3 of 481 or 0.62%
# finished 4 of 481 or 0.83%
# finished 5 of 481 or 1.04%
# finished 6 of 481 or 1.25%
# finished 7 of 481 or 1.46%
# finished 8 of 481 or 1.66%
# finished 9 of 481 or 1.87%
# finished 10 of 481 or 2.08%
# finished 11 of 481 or 2.29%
# finished 12 of 481 or 2.49%
# finished 13 of 481 or 2.70%
# finished 14 of 481 or 2.91%
# finished 15 of 481 or 3.12%
# finished 16 of 481 or 3.33%
# finished 17 of 481 or 3.53%
# finished 18 of 481 or 3.74%
# finished 19 of 481 or 3.95%
# finished 20 of 481 or 4.16%
# finished 21 of 481 or 4.37%
# finished 22 of 481 or 4.57%
# finished 23 of 481 or 4.78%
# finished 24 of 481 or 4.99%
# finished 25 of 481 or 5.20%
# finished 26 of 481 or 5.41%
# finished 27 of 481 or 5.61%
# finished 28 of 481 or 5.82%
# finished 29 of 481 or 6.03%
# finished 30 of 481 or 6.24%
# finished 31 of 481 or 6.44%
# finished 32 of 481 or 6.65%
# finished 33 of 481 or 6.86%
# finished 34 of 481 or 7.07%
# finished 35 of 481 or 7.28%
# finished 36 of 481 or 7.48%
# finished 37 of 481 or 7.69%
# finished 38 of 481 or 7.90%
# finished 39 of 481 or 8.11%
# finished 40 of 481 or 8.32%
# finished 41 of 481 or 8.52%
# finished 42 of 481 or 8.73%
# finished 43 of 481 or 8.94%
# finished 44 of 481 or 9.15%
# finished 45 of 481 or 9.36%
# finished 46 of 481 or 9.56%
# finished 47 of 481 or 9.77%
# finished 48 of 481 or 9.98%
# finished 49 of 481 or 10.19%
# finished 50 of 481 or 10.40%
# finished 51 of 481 or 10.60%
# finished 52 of 481 or 10.81%
# finished 53 of 481 or 11.02%
# finished 54 of 481 or 11.23%
# finished 55 of 481 or 11.43%
# finished 56 of 481 or 11.64%
# finished 57 of 481 or 11.85%
# finished 58 of 481 or 12.06%
# finished 59 of 481 or 12.27%
# finished 60 of 481 or 12.47%
# finished 61 of 481 or 12.68%
# finished 62 of 481 or 12.89%
# finished 63 of 481 or 13.10%
# finished 64 of 481 or 13.31%
# finished 65 of 481 or 13.51%
# finished 66 of 481 or 13.72%
# finished 67 of 481 or 13.93%
# finished 68 of 481 or 14.14%
# finished 69 of 481 or 14.35%
# finished 70 of 481 or 14.55%
# finished 71 of 481 or 14.76%
# finished 72 of 481 or 14.97%
# finished 73 of 481 or 15.18%
# finished 74 of 481 or 15.38%
# finished 75 of 481 or 15.59%
# finished 76 of 481 or 15.80%
# finished 77 of 481 or 16.01%
# finished 78 of 481 or 16.22%
# finished 79 of 481 or 16.42%
# finished 80 of 481 or 16.63%
# finished 81 of 481 or 16.84%
# finished 82 of 481 or 17.05%
# finished 83 of 481 or 17.26%
# finished 84 of 481 or 17.46%
# finished 85 of 481 or 17.67%
# finished 86 of 481 or 17.88%
# finished 87 of 481 or 18.09%
# finished 88 of 481 or 18.30%
# finished 89 of 481 or 18.50%
# finished 90 of 481 or 18.71%
# finished 91 of 481 or 18.92%
# finished 92 of 481 or 19.13%
# finished 93 of 481 or 19.33%
# finished 94 of 481 or 19.54%
# finished 95 of 481 or 19.75%
# finished 96 of 481 or 19.96%
# finished 97 of 481 or 20.17%
# finished 98 of 481 or 20.37%
# finished 99 of 481 or 20.58%
# finished 100 of 481 or 20.79%
# finished 101 of 481 or 21.00%
# finished 102 of 481 or 21.21%
# finished 103 of 481 or 21.41%
# finished 104 of 481 or 21.62%
# finished 105 of 481 or 21.83%
# finished 106 of 481 or 22.04%
# finished 107 of 481 or 22.25%
# finished 108 of 481 or 22.45%
# finished 109 of 481 or 22.66%
# finished 110 of 481 or 22.87%
# finished 111 of 481 or 23.08%
# finished 112 of 481 or 23.28%
# finished 113 of 481 or 23.49%
# finished 114 of 481 or 23.70%
# finished 115 of 481 or 23.91%
# finished 116 of 481 or 24.12%
# finished 117 of 481 or 24.32%
# finished 118 of 481 or 24.53%
# finished 119 of 481 or 24.74%
# finished 120 of 481 or 24.95%
# finished 121 of 481 or 25.16%
# finished 122 of 481 or 25.36%
# finished 123 of 481 or 25.57%
# finished 124 of 481 or 25.78%
# finished 125 of 481 or 25.99%
# finished 126 of 481 or 26.20%
# finished 127 of 481 or 26.40%
# finished 128 of 481 or 26.61%
# finished 129 of 481 or 26.82%
# finished 130 of 481 or 27.03%
# finished 131 of 481 or 27.23%
# finished 132 of 481 or 27.44%
# finished 133 of 481 or 27.65%
# finished 134 of 481 or 27.86%
# finished 135 of 481 or 28.07%
# finished 136 of 481 or 28.27%
# finished 137 of 481 or 28.48%
# finished 138 of 481 or 28.69%
# finished 139 of 481 or 28.90%
# finished 140 of 481 or 29.11%
# finished 141 of 481 or 29.31%
# finished 142 of 481 or 29.52%
# finished 143 of 481 or 29.73%
# finished 144 of 481 or 29.94%
# finished 145 of 481 or 30.15%
# finished 146 of 481 or 30.35%
# finished 147 of 481 or 30.56%
# finished 148 of 481 or 30.77%
# finished 149 of 481 or 30.98%
# finished 150 of 481 or 31.19%
# finished 151 of 481 or 31.39%
# finished 152 of 481 or 31.60%
# finished 153 of 481 or 31.81%
# finished 154 of 481 or 32.02%
# finished 155 of 481 or 32.22%
# finished 156 of 481 or 32.43%
# finished 157 of 481 or 32.64%
# finished 158 of 481 or 32.85%
# finished 159 of 481 or 33.06%
# finished 160 of 481 or 33.26%
# finished 161 of 481 or 33.47%
# finished 162 of 481 or 33.68%
# finished 163 of 481 or 33.89%
# finished 164 of 481 or 34.10%
# finished 165 of 481 or 34.30%
# finished 166 of 481 or 34.51%
# finished 167 of 481 or 34.72%
# finished 168 of 481 or 34.93%
# finished 169 of 481 or 35.14%
# finished 170 of 481 or 35.34%
# finished 171 of 481 or 35.55%
# finished 172 of 481 or 35.76%
# finished 173 of 481 or 35.97%
# finished 174 of 481 or 36.17%
# finished 175 of 481 or 36.38%
# finished 176 of 481 or 36.59%
# finished 177 of 481 or 36.80%
# finished 178 of 481 or 37.01%
# finished 179 of 481 or 37.21%
# finished 180 of 481 or 37.42%
# finished 181 of 481 or 37.63%
# finished 182 of 481 or 37.84%
# finished 183 of 481 or 38.05%
# finished 184 of 481 or 38.25%
# finished 185 of 481 or 38.46%
# finished 186 of 481 or 38.67%
# finished 187 of 481 or 38.88%
# finished 188 of 481 or 39.09%
# finished 189 of 481 or 39.29%
# finished 190 of 481 or 39.50%
# finished 191 of 481 or 39.71%
# finished 192 of 481 or 39.92%
# finished 193 of 481 or 40.12%
# finished 194 of 481 or 40.33%
# finished 195 of 481 or 40.54%
# finished 196 of 481 or 40.75%
# finished 197 of 481 or 40.96%
# finished 198 of 481 or 41.16%
# finished 199 of 481 or 41.37%
# finished 200 of 481 or 41.58%
# finished 201 of 481 or 41.79%
# finished 202 of 481 or 42.00%
# finished 203 of 481 or 42.20%
# finished 204 of 481 or 42.41%
# finished 205 of 481 or 42.62%
# finished 206 of 481 or 42.83%
# finished 207 of 481 or 43.04%
# finished 208 of 481 or 43.24%
# finished 209 of 481 or 43.45%
# finished 210 of 481 or 43.66%
# finished 211 of 481 or 43.87%
# finished 212 of 481 or 44.07%
# finished 213 of 481 or 44.28%
# finished 214 of 481 or 44.49%
# finished 215 of 481 or 44.70%
# finished 216 of 481 or 44.91%
# finished 217 of 481 or 45.11%
# finished 218 of 481 or 45.32%
# finished 219 of 481 or 45.53%
# finished 220 of 481 or 45.74%
# finished 221 of 481 or 45.95%
# finished 222 of 481 or 46.15%
# finished 223 of 481 or 46.36%
# finished 224 of 481 or 46.57%
# finished 225 of 481 or 46.78%
# finished 226 of 481 or 46.99%
# finished 227 of 481 or 47.19%
# finished 228 of 481 or 47.40%
# finished 229 of 481 or 47.61%
# finished 230 of 481 or 47.82%
# finished 231 of 481 or 48.02%
# finished 232 of 481 or 48.23%
# finished 233 of 481 or 48.44%
# finished 234 of 481 or 48.65%
# finished 235 of 481 or 48.86%
# finished 236 of 481 or 49.06%
# finished 237 of 481 or 49.27%
# finished 238 of 481 or 49.48%
# finished 239 of 481 or 49.69%
# finished 240 of 481 or 49.90%
# finished 241 of 481 or 50.10%
# finished 242 of 481 or 50.31%
# finished 243 of 481 or 50.52%
# finished 244 of 481 or 50.73%
# finished 245 of 481 or 50.94%
# finished 246 of 481 or 51.14%
# finished 247 of 481 or 51.35%
# finished 248 of 481 or 51.56%
# finished 249 of 481 or 51.77%
# finished 250 of 481 or 51.98%
# finished 251 of 481 or 52.18%
# finished 252 of 481 or 52.39%
# finished 253 of 481 or 52.60%
# finished 254 of 481 or 52.81%
# finished 255 of 481 or 53.01%
# finished 256 of 481 or 53.22%
# finished 257 of 481 or 53.43%
# finished 258 of 481 or 53.64%
# finished 259 of 481 or 53.85%
# finished 260 of 481 or 54.05%
# finished 261 of 481 or 54.26%
# finished 262 of 481 or 54.47%
# finished 263 of 481 or 54.68%
# finished 264 of 481 or 54.89%
# finished 265 of 481 or 55.09%
# finished 266 of 481 or 55.30%
# finished 267 of 481 or 55.51%
# finished 268 of 481 or 55.72%
# finished 269 of 481 or 55.93%
# finished 270 of 481 or 56.13%
# finished 271 of 481 or 56.34%
# finished 272 of 481 or 56.55%
# finished 273 of 481 or 56.76%
# finished 274 of 481 or 56.96%
# finished 275 of 481 or 57.17%
# finished 276 of 481 or 57.38%
# finished 277 of 481 or 57.59%
# finished 278 of 481 or 57.80%
# finished 279 of 481 or 58.00%
# finished 280 of 481 or 58.21%
# finished 281 of 481 or 58.42%
# finished 282 of 481 or 58.63%
# finished 283 of 481 or 58.84%
# finished 284 of 481 or 59.04%
# finished 285 of 481 or 59.25%
# finished 286 of 481 or 59.46%
# finished 287 of 481 or 59.67%
# finished 288 of 481 or 59.88%
# finished 289 of 481 or 60.08%
# finished 290 of 481 or 60.29%
# finished 291 of 481 or 60.50%
# finished 292 of 481 or 60.71%
# finished 293 of 481 or 60.91%
# finished 294 of 481 or 61.12%
# finished 295 of 481 or 61.33%
# finished 296 of 481 or 61.54%
# finished 297 of 481 or 61.75%
# finished 298 of 481 or 61.95%
# finished 299 of 481 or 62.16%
# finished 300 of 481 or 62.37%
# finished 301 of 481 or 62.58%
# finished 302 of 481 or 62.79%
# finished 303 of 481 or 62.99%
# finished 304 of 481 or 63.20%
# finished 305 of 481 or 63.41%
# finished 306 of 481 or 63.62%
# finished 307 of 481 or 63.83%
# finished 308 of 481 or 64.03%
# finished 309 of 481 or 64.24%
# finished 310 of 481 or 64.45%
# finished 311 of 481 or 64.66%
# finished 312 of 481 or 64.86%
# finished 313 of 481 or 65.07%
# finished 314 of 481 or 65.28%
# finished 315 of 481 or 65.49%
# finished 316 of 481 or 65.70%
# finished 317 of 481 or 65.90%
# finished 318 of 481 or 66.11%
# finished 319 of 481 or 66.32%
# finished 320 of 481 or 66.53%
# finished 321 of 481 or 66.74%
# finished 322 of 481 or 66.94%
# finished 323 of 481 or 67.15%
# finished 324 of 481 or 67.36%
# finished 325 of 481 or 67.57%
# finished 326 of 481 or 67.78%
# finished 327 of 481 or 67.98%
# finished 328 of 481 or 68.19%
# finished 329 of 481 or 68.40%
# finished 330 of 481 or 68.61%
# finished 331 of 481 or 68.81%
# finished 332 of 481 or 69.02%
# finished 333 of 481 or 69.23%
# finished 334 of 481 or 69.44%
# finished 335 of 481 or 69.65%
# finished 336 of 481 or 69.85%
# finished 337 of 481 or 70.06%
# finished 338 of 481 or 70.27%
# finished 339 of 481 or 70.48%
# finished 340 of 481 or 70.69%
# finished 341 of 481 or 70.89%
# finished 342 of 481 or 71.10%
# finished 343 of 481 or 71.31%
# finished 344 of 481 or 71.52%
# finished 345 of 481 or 71.73%
# finished 346 of 481 or 71.93%
# finished 347 of 481 or 72.14%
# finished 348 of 481 or 72.35%
# finished 349 of 481 or 72.56%
# finished 350 of 481 or 72.77%
# finished 351 of 481 or 72.97%
# finished 352 of 481 or 73.18%
# finished 353 of 481 or 73.39%
# finished 354 of 481 or 73.60%
# finished 355 of 481 or 73.80%
# finished 356 of 481 or 74.01%
# finished 357 of 481 or 74.22%
# finished 358 of 481 or 74.43%
# finished 359 of 481 or 74.64%
# finished 360 of 481 or 74.84%
# finished 361 of 481 or 75.05%
# finished 362 of 481 or 75.26%
# finished 363 of 481 or 75.47%
# finished 364 of 481 or 75.68%
# finished 365 of 481 or 75.88%
# finished 366 of 481 or 76.09%
# finished 367 of 481 or 76.30%
# finished 368 of 481 or 76.51%
# finished 369 of 481 or 76.72%
# finished 370 of 481 or 76.92%
# finished 371 of 481 or 77.13%
# finished 372 of 481 or 77.34%
# finished 373 of 481 or 77.55%
# finished 374 of 481 or 77.75%
# finished 375 of 481 or 77.96%
# finished 376 of 481 or 78.17%
# finished 377 of 481 or 78.38%
# finished 378 of 481 or 78.59%
# finished 379 of 481 or 78.79%
# finished 380 of 481 or 79.00%
# finished 381 of 481 or 79.21%
# finished 382 of 481 or 79.42%
# finished 383 of 481 or 79.63%
# finished 384 of 481 or 79.83%
# finished 385 of 481 or 80.04%
# finished 386 of 481 or 80.25%
# finished 387 of 481 or 80.46%
# finished 388 of 481 or 80.67%
# finished 389 of 481 or 80.87%
# finished 390 of 481 or 81.08%
# finished 391 of 481 or 81.29%
# finished 392 of 481 or 81.50%
# finished 393 of 481 or 81.70%
# finished 394 of 481 or 81.91%
# finished 395 of 481 or 82.12%
# finished 396 of 481 or 82.33%
# finished 397 of 481 or 82.54%
# finished 398 of 481 or 82.74%
# finished 399 of 481 or 82.95%
# finished 400 of 481 or 83.16%
# finished 401 of 481 or 83.37%
# finished 402 of 481 or 83.58%
# finished 403 of 481 or 83.78%
# finished 404 of 481 or 83.99%
# finished 405 of 481 or 84.20%
# finished 406 of 481 or 84.41%
# finished 407 of 481 or 84.62%
# finished 408 of 481 or 84.82%
# finished 409 of 481 or 85.03%
# finished 410 of 481 or 85.24%
# finished 411 of 481 or 85.45%
# finished 412 of 481 or 85.65%
# finished 413 of 481 or 85.86%
# finished 414 of 481 or 86.07%
# finished 415 of 481 or 86.28%
# finished 416 of 481 or 86.49%
# finished 417 of 481 or 86.69%
# finished 418 of 481 or 86.90%
# finished 419 of 481 or 87.11%
# finished 420 of 481 or 87.32%
# finished 421 of 481 or 87.53%
# finished 422 of 481 or 87.73%
# finished 423 of 481 or 87.94%
# finished 424 of 481 or 88.15%
# finished 425 of 481 or 88.36%
# finished 426 of 481 or 88.57%
# finished 427 of 481 or 88.77%
# finished 428 of 481 or 88.98%
# finished 429 of 481 or 89.19%
# finished 430 of 481 or 89.40%
# finished 431 of 481 or 89.60%
# finished 432 of 481 or 89.81%
# finished 433 of 481 or 90.02%
# finished 434 of 481 or 90.23%
# finished 435 of 481 or 90.44%
# finished 436 of 481 or 90.64%
# finished 437 of 481 or 90.85%
# finished 438 of 481 or 91.06%
# finished 439 of 481 or 91.27%
# finished 440 of 481 or 91.48%
# finished 441 of 481 or 91.68%
# finished 442 of 481 or 91.89%
# finished 443 of 481 or 92.10%
# finished 444 of 481 or 92.31%
# finished 445 of 481 or 92.52%
# finished 446 of 481 or 92.72%
# finished 447 of 481 or 92.93%
# finished 448 of 481 or 93.14%
# finished 449 of 481 or 93.35%
# finished 450 of 481 or 93.56%
# finished 451 of 481 or 93.76%
# finished 452 of 481 or 93.97%
# finished 453 of 481 or 94.18%
# finished 454 of 481 or 94.39%
# finished 455 of 481 or 94.59%
# finished 456 of 481 or 94.80%
# finished 457 of 481 or 95.01%
# finished 458 of 481 or 95.22%
# finished 459 of 481 or 95.43%
# finished 460 of 481 or 95.63%
# finished 461 of 481 or 95.84%
# finished 462 of 481 or 96.05%
# finished 463 of 481 or 96.26%
# finished 464 of 481 or 96.47%
# finished 465 of 481 or 96.67%
# finished 466 of 481 or 96.88%
# finished 467 of 481 or 97.09%
# finished 468 of 481 or 97.30%
# finished 469 of 481 or 97.51%
# finished 470 of 481 or 97.71%
# finished 471 of 481 or 97.92%
# finished 472 of 481 or 98.13%
# finished 473 of 481 or 98.34%
# finished 474 of 481 or 98.54%
# finished 475 of 481 or 98.75%
# finished 476 of 481 or 98.96%
# finished 477 of 481 or 99.17%
# finished 478 of 481 or 99.38%
# finished 479 of 481 or 99.58%
# finished 480 of 481 or 99.79%

# %%
#fix dead link for 3 failed players 
#failed_players=['Todd Reirden','Erik Reitz','Mike Vernon']
for p in failed_players:
    gamelogd = loglink(players.loc[players['player']==p,'link'].values[0])
    log = gamelogger(gamelogd)
    uid = players.loc[players['player']==p,'unique_id'].values[0]
    print(uid)
    log.to_csv('player_gamelogs\\'+uid+'.txt')
