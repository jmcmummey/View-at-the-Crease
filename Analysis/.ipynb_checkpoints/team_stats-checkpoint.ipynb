# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# Give the team, the year and the game #, get the team stats including:
# <ul>
#     <li>Record to date for the team and their opponent</li>
#     <li>Outcomes of last 5 contests - inlcuding previous year</li>
#     <li>Outcomes of last 5 contests for each team</li>
# </ul>

# %% [markdown]
# <h3>SQLite Handling functions</h3>
# <p>Use Pandas to import dataframe into SQLlite</p>

# %%
DB = "..\\Data\\hockey_data_goalies.db"

#SQL Handle functions
def run_query(q):
    with sqlite3.connect(DB) as conn:
        x = pd.read_sql(q,conn)
    return x
   
#send command
def run_command(c):
    with sqlite3.connect(DB) as conn:
        conn.isolation_level = None
        return conn.execute(c)
    
#show tables
def show_tables():
    r = """
    Select name,type
    FROM sqlite_master
    WHERE type in ("table","view");
        """
    return run_query(r)

# %% [markdown]
# Statistic functions

# %%
def sos_calc(year,game_no,nme,wind=[0]):
    """
        CALCULATES THE SOS FOR THE TEAM entered faced before a given date
    INPUT:
        year: the current season (YYYY-YYYY+1)
        gamedate: the game_no for the current game previous games are [0-game_no-1]
        nme: the team abbr to calculate the SOS for
        RETURN:
        sos: the computed sos statistics sum(no_times_faced*(goalsfor-goalsagainst)/no_games)/no_games
    """
    
    sos = 0
    
    #get the details on the game
    q = ("""SELECT * 
            FROM team_log 
            WHERE team_id=\"{0}\"
            AND (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12) > {1}
            AND (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12) < {2}
            """.format(nme,int(year) + .66,int(year)+1.66))
    games = run_query(q)
    games['date_game'] = games['date_game'].astype('datetime64')
    
    gamedate = games.at[game_no,'date_game']

    if game_no>0:
        #list of teams faced to date (and number of times)
        if len(wind) ==1:
            teams_faced = games.loc[games['date_game']<gamedate,'opp_name'].value_counts()
        else:
            teams_faced = games.loc[wind,'opp_name'].value_counts()
       
        #get list of games played in the league that season up until the gameday
        q = ("""SELECT * 
                FROM team_log 
                WHERE (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12) > {1}
                AND (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12) < {2}
                """.format(nme,int(year) + .66,int(year)+1.66))
        temp_games = run_query(q)
        temp_games['date_game'] = temp_games['date_game'].astype('datetime64')

        #calculate statistics for each team
        goals = temp_games[temp_games['date_game']<gamedate].groupby('team_id').agg([sum,'count'])

        diff = (goals['goals']['sum']-goals['opp_goals']['sum'])/goals['goals']['count'] #calculates metric for all teams to date

        for eachteam in teams_faced.index:
            #get team_abbr

            q = '''SELECT team_abbr FROM team_list WHERE team_name=\"{0}\" AND CAST(SUBSTR(years_active,6,9) AS INT)>{1}'''.format(eachteam,int(year))
            nme = (run_query(q)['team_abbr'].values)[0]
            sos = sos + teams_faced[eachteam]*diff[nme]
        if len(wind) == 1:
            return sos/game_no
        else:
            return sos/wind.sum()
    else:
        return 0

# %%
#inputs
team_value = 'ANA'
year_value = 2016
game_num = 56 # for the team

# %% [markdown]
# <h2>Get record to date</h2>

# %%
#find the game date
q = ("""SELECT *
        FROM team_log 
        WHERE team_id=\"{0}\" 
        AND (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12) > {1}
        AND (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12) < {2}
        AND game_number={3}""".format(team_value,int(year_value) + .66,int(year_value)+1.66,game_num))
game_selected = run_query(q)
game_date = game_selected['date_game'].values[0]
opp_name =  game_selected['opp_name'].values[0]
q = """SELECT * 
       FROM team_list 
       WHERE team_name=\"{0}\" 
       AND CAST(SUBSTR(years_active,6,9) as INT)>{1}""".format(opp_name,year_value)
opp_abbr = run_query(q).at[0,'team_abbr']
print(game_date,opp_name,opp_abbr)

#now get records
#for hometeam
q = ("""SELECT *
        FROM team_log 
        WHERE team_id=\"{0}\" 
        AND (CAST(SUBSTR(date_game,1,4) AS FLOAT)+CAST(SUBSTR(date_game,6,7) AS FLOAT)/12
#                  opp_name  goals  opp_goals game_outcome overtimes  shots  \
# 0            Dallas Stars      2          4            L      None     35
# 1     Pittsburgh Penguins      2          3            L      None     36
# 2      New York Islanders      2          3            L        OT     26
# 3       New Jersey Devils      1          2            L      None     24
# 4     Philadelphia Flyers      3          2            W      None     26
# 5       Vancouver Canucks      4          2            W      None     37
# 6         San Jose Sharks      1          2            L        OT     20
# 7     Nashville Predators      6          1            W      None     26
# 8   Columbus Blue Jackets      0          4            L      None     35
# 9       Los Angeles Kings      4          0            W      None     21
# 10    Pittsburgh Penguins      1          5            L      None     33
# 11        Arizona Coyotes      5          1            W      None     33
# 12         Calgary Flames      4          1            W      None     21
# 13  Columbus Blue Jackets      2          3            L        OT     32
# 14    Carolina Hurricanes      4          2            W      None     27
# 15    Nashville Predators      0          5            L      None     27
# 16        Edmonton Oilers      4          1            W      None     27
# 17      New Jersey Devils      3          2            W      None     23
# 18      Los Angeles Kings      2          3            L      None     30
# 19     New York Islanders      2          3            L        SO     41
# 20     Chicago Blackhawks      2          3            L      None     36
# 21        San Jose Sharks      3          2            W      None     26
# 22     Montreal Canadiens      2          1            W      None     38
# 23      Vancouver Canucks      3          1            W      None     24
# 24        Edmonton Oilers      2          3            L        OT     33
# 25         Calgary Flames      3          8            L      None     33
# 26    Carolina Hurricanes      6          5            W        SO     38
# 27        San Jose Sharks      3          2            W      None     32
# 28        Ottawa Senators      5          1            W      None     32
# 29           Dallas Stars      2          6            L      None     36
# 30          Boston Bruins      4          3            W      None     27
# 31      Detroit Red Wings      4          6            L      None     25
# 32    Toronto Maple Leafs      3          2            W      None     28
# 33     Montreal Canadiens      1          5            L      None     13
# 34        Ottawa Senators      1          2            L        OT     25
# 35        San Jose Sharks      2          3            L        OT     36
# 36         Calgary Flames      3          1            W      None     25
# 37      Vancouver Canucks      2          3            L        OT     26
# 38    Philadelphia Flyers      4          3            W        SO     25
# 39      Detroit Red Wings      2          0            W      None     24
# 40        Arizona Coyotes      3          2            W        OT     35
# 41         Minnesota Wild      1          2            L      None     24
# 42           Dallas Stars      2          0            W      None     38
# 43     Colorado Avalanche      4          1            W      None     32
# 44        Arizona Coyotes      3          0            W      None     23
# 45        St. Louis Blues      1          2            L        OT     23
# 46    Tampa Bay Lightning      2          1            W        OT     21
# 47     Colorado Avalanche      2          1            W      None     36
# 48         Minnesota Wild      3          5            L      None     29
# 49          Winnipeg Jets      3          2            W      None     27
# 50        Edmonton Oilers      0          4            L      None     26
# 51     Colorado Avalanche      5          1            W      None     31
# 52       Florida Panthers      1          2            L      None     23
# 53    Tampa Bay Lightning      2          3            L        SO     16
# 54       New York Rangers      1          4            L      None     44
# 55         Buffalo Sabres      5          2            W      None     44
#
#     shots_against
# 0              20
# 1              45
# 2              30
# 3              28
# 4              22
# 5              19
# 6              36
# 7              29
# 8              37
# 9              30
# 10             34
# 11             22
# 12             26
# 13             18
# 14             30
# 15             27
# 16             34
# 17             29
# 18             29
# 19             35
# 20             25
# 21             23
# 22             40
# 23             28
# 24             32
# 25             25
# 26             34
# 27             24
# 28             22
# 29             27
# 30             34
# 31             32
# 32             35
# 33             34
# 34             18
# 35             25
# 36             32
# 37             26
# 38             55
# 39             23
# 40             23
# 41             36
# 42             34
# 43             34
# 44             26
# 45             25
# 46             28
# 47             22
# 48             25
# 49             33
# 50             23
# 51             29
# 52             37
# 53             37
# 54             20
# 55             26
